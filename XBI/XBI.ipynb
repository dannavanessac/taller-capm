# %% [markdown]
# ### Descargar datos de XBI

# %%
# Instalar la librería yfinance para descargar datos financieros
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.13/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.11.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.16.2)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Definir el ticker de XBI
ticker = 'XBI'

# Definir la fecha de corte (hasta el 24 de agosto de 2026)
end_date = '2026-08-24'

# Definir la fecha de inicio (desde el 25 de agosto de 2021)
start_date = '2021-08-25'

# Descargar los datos históricos
df_xbi = yf.download(ticker, start=start_date, end=end_date)

# Mostrar las primeras filas del DataFrame
print(f"\n\nDatos de XBI desde {start_date} hasta {end_date}:")
display(df_xbi.head())
# Out:
# /tmp/ipykernel_6194/3803643451.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_xbi = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Datos de XBI desde 2021-08-25 hasta 2026-08-24:
# Price            Close        High         Low        Open   Volume
# Ticker             XBI         XBI         XBI         XBI      XBI
# Date
# 2021-08-25  128.344681  129.070068  125.651781  126.556040  5395700
# 2021-08-26  127.768349  130.222758  127.192008  128.086321  5666100
# 2021-08-27  131.196579  132.150526  127.659053  128.215516  6466600
# 2021-08-30  130.799088  132.756653  130.262488  131.812638  4893700
# 2021-08-31  132.001450  132.746715  130.669912  130.669912  3680100

# %% [markdown]
# ### Añadir nuevas columnas al dataset

# %%
# 1. Retornos Logarítmicos
df_xbi['Log_Returns'] = np.log(df_xbi['Close'] / df_xbi['Close'].shift(1))

# 2. Volumen Monetario
df_xbi['Monetary_Volume'] = df_xbi['Volume'] * df_xbi['Close']

# Mostrar las primeras filas con las nuevas columnas
print("DataFrame con las nuevas columnas:")
display(df_xbi.head())
# Out:
# DataFrame con las nuevas columnas:
# Price            Close        High         Low        Open   Volume  \
# Ticker             XBI         XBI         XBI         XBI      XBI
# Date
# 2021-08-25  128.344681  129.070068  125.651781  126.556040  5395700
# 2021-08-26  127.768349  130.222758  127.192008  128.086321  5666100
# 2021-08-27  131.196579  132.150526  127.659053  128.215516  6466600
# 2021-08-30  130.799088  132.756653  130.262488  131.812638  4893700
# 2021-08-31  132.001450  132.746715  130.669912  130.669912  3680100
#
# Price      Log_Returns Monetary_Volume
# Ticker
# Date
# 2021-08-25         NaN    6.925094e+08
# 2021-08-26   -0.004501    7.239482e+08
# 2021-08-27    0.026478    8.483958e+08
# 2021-08-30   -0.003034    6.400915e+08
# 2021-08-31    0.009150    4.857785e+08

# %% [markdown]
# ### Crear una tabla aparte con estadísticas

# %%
# Calcular las métricas solicitadas

# Retorno promedio diario
mean_daily_return = df_xbi['Log_Returns'].mean()

# Retorno acumulado
cumulative_return = (df_xbi['Close'].iloc[-1] / df_xbi['Close'].iloc[0]) - 1

# Retorno anualizado (asumiendo 252 días hábiles en un año para retornos logarítmicos)
annualized_return = mean_daily_return * 252

# Desviación estándar de retornos diarios
std_daily_returns = df_xbi['Log_Returns'].std()

# Volatilidad anualizada
annualized_volatility = std_daily_returns * np.sqrt(252)

# Varianza de retornos diarios
variance_daily_returns = df_xbi['Log_Returns'].var()

# Asimetría de retornos diarios
skewness_daily_returns = df_xbi['Log_Returns'].skew()

# Curtosis de retornos diarios
kurtosis_daily_returns = df_xbi['Log_Returns'].kurt()

# Crear un DataFrame para las estadísticas
stats_df = pd.DataFrame({
    'Métrica': [
        'Retorno promedio diario',
        'Retorno acumulado',
        'Retorno anualizado',
        'Desviación estándar de retornos diarios',
        'Volatilidad anualizada',
        'Varianza de retornos diarios',
        'Asimetría de retornos diarios',
        'Curtosis de retornos diarios'
    ],
    'Valor': [
        mean_daily_return,
        cumulative_return,
        annualized_return,
        std_daily_returns,
        annualized_volatility,
        variance_daily_returns,
        skewness_daily_returns,
        kurtosis_daily_returns
    ]
})

# Mostrar la tabla de estadísticas
print("Tabla de Estadísticas de Retornos de XBI:")
display(stats_df)
# Out:
# Tabla de Estadísticas de Retornos de XBI:
#                                    Métrica  \
# 0                  Retorno promedio diario
# 1                        Retorno acumulado
# 2                       Retorno anualizado
# 3  Desviación estándar de retornos diarios
# 4                   Volatilidad anualizada
# 5             Varianza de retornos diarios
# 6            Asimetría de retornos diarios
# 7             Curtosis de retornos diarios
#
#                                    Valor
# 0                               0.000204
# 1  Ticker
# XBI    0.291288
# dtype: float64
# 2                               0.051455
# 3                               0.020388
# 4                               0.323649
# 5                               0.000416
# 6                              -0.078708
# 7                                0.79779

# %%
df_xbi.to_csv('df_xbi.csv', index=True)
stats_df.to_csv('xbi_stats.csv', index=False)
print("df_xbi.csv and xbi_stats.csv have been downloaded.")
# Out:
# df_xbi.csv and xbi_stats.csv have been downloaded.
